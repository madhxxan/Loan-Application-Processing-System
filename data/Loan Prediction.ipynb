# %%
#===========Importing Neccessaryy library and module========

#===========Importing Classifier=========
from sklearn.ensemble import RandomForestClassifier

#==========Importing numpy for multidimensional array
import numpy as np

#=========importing matplotlib for Plotting Graph==========
import matplotlib.pyplot as plt

#=========Loadig model selection for splitting the dataset==============
from sklearn.model_selection import train_test_split

#=========Importing models for classification efficiency
from sklearn.metrics import accuracy_score, classification_report

#========Importing library for dealing with DataFrame=====
import pandas as pd

# %%
#========Loading the dataset======
loan = pd.read_csv('loan.csv')

# %%
#==========Visualising the Dataset======
loan.head(5)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
len(loan)
# Out:
# 614

# %%
"""
We have to check if the dataset contain null values so as we 
can replace them with mean values to improve our classification 

and 

we have to Encode string with Numerical values such as Gender and Education
and Loan status
"""
# Out:
# '\nWe have to check if the dataset contain null values so as we \ncan replace them with mean values to improve our classification \n\nand \n\nwe have to Encode string with Numerical values such as Gender and Education\nand Loan status\n'

# %%
#=======Checking the presence of Null Values=========

#==== We use built in Function isnull() and sum()

loan.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
pip install scikit-learn==0.20.4
# Out:
# Collecting scikit-learn==0.20.4
#   Downloading scikit-learn-0.20.4.tar.gz (11.7 MB)
#      ---------------------------------------- 0.0/11.7 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.7 MB 1.4 MB/s eta 0:00:09
#      ---------------------------------------- 0.1/11.7 MB 1.1 MB/s eta 0:00:11
#       --------------------------------------- 0.2/11.7 MB 1.2 MB/s eta 0:00:10
#       --------------------------------------- 0.3/11.7 MB 1.6 MB/s eta 0:00:08
#      - -------------------------------------- 0.5/11.7 MB 2.3 MB/s eta 0:00:05
#      --- ------------------------------------ 1.0/11.7 MB 3.5 MB/s eta 0:00:04
#      ----- ---------------------------------- 1.6/11.7 MB 4.9 MB/s eta 0:00:03
#      ------- -------------------------------- 2.1/11.7 MB 6.1 MB/s eta 0:00:02
#      ------- -------------------------------- 2.2/11.7 MB 5.8 MB/s eta 0:00:02
#      ---------- ----------------------------- 2.9/11.7 MB 6.7 MB/s eta 0:00:02
#      --------------- ------------------------ 4.5/11.7 MB 9.1 MB/s eta 0:00:01
#      ----------------- ---------------------- 5.0/11.7 MB 9.1 MB/s eta 0:00:01
#      -------------------- ------------------- 6.1/11.7 MB 10.6 MB/s eta 0:00:01
#      -------------------- ------------------- 6.1/11.7 MB 10.6 MB/s eta 0:00:01
#      -------------------------- ------------- 7.9/11.7 MB 11.2 MB/s eta 0:00:01
#      ----------------------------- ---------- 8.7/11.7 MB 11.6 MB/s eta 0:00:01
#      ------------------------------- -------- 9.2/11.7 MB 11.8 MB/s eta 0:00:01
#      ---------------------------------- ----- 9.9/11.7 MB 12.0 MB/s eta 0:00:01
#      ---------------------------------- ---- 10.3/11.7 MB 13.1 MB/s eta 0:00:01
#      ---------------------------------- ---- 10.3/11.7 MB 13.1 MB/s eta 0:00:01
#      ------------------------------------ -- 11.0/11.7 MB 14.2 MB/s eta 0:00:01
#      --------------------------------------  11.7/11.7 MB 14.9 MB/s eta 0:00:01
#      --------------------------------------- 11.7/11.7 MB 14.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.8.2 in c:\users\user\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn==0.20.4) (1.24.3)
# Requirement already satisfied: scipy>=0.13.3 in c:\users\user\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn==0.20.4) (1.10.1)
# Building wheels for collected packages: scikit-learn
#   Building wheel for scikit-learn (setup.py): started
#   Building wheel for scikit-learn (setup.py): finished with status 'error'
#   Running setup.py clean for scikit-learn
# Failed to build scikit-learn
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [708 lines of output]
#   C:\Users\user\AppData\Local\Temp\pip-install-05dhrub9\scikit-learn_0b73a366545b41d09a8528ab0b05dc2c\setup.py:12: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#     from pkg_resources import parse_version
#   Partial import of sklearn during the build process.
#   C:\Users\user\AppData\Local\Temp\pip-install-05dhrub9\scikit-learn_0b73a366545b41d09a8528ab0b05dc2c\setup.py:242: DeprecationWarning:
#
#     `numpy.distutils` is deprecated since NumPy 1.23.0, as a result
#     of the deprecation of `distutils` itself. It will be removed for
#     Python >= 3.12. For older Python versions it will remain present.
#     It is recommended to use `setuptools < 60.0` for those Python versions.
#     For more details, see:
#       https://numpy.org/devdocs/reference/distutils_status_migration.html
#
#
#     from numpy.distutils.core import setup
#   INFO: blas_opt_info:
#   INFO: blas_armpl_info:
#   INFO: No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   INFO: customize MSVCCompiler
#   INFO:   libraries armpl_lp64_mp not found in ['c:\\users\\user\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\user\\appdata\\local\\programs\\python\\python38\\libs']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: blas_mkl_info:
#   INFO:   libraries mkl_rt not found in ['c:\\users\\user\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\user\\appdata\\local\\programs\\python\\python38\\libs']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: blis_info:
#   INFO:   libraries blis not found in ['c:\\users\\user\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\user\\appdata\\local\\programs\\python\\python38\\libs']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: openblas_info:
#   INFO:   libraries openblas not found in ['c:\\users\\user\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\user\\appdata\\local\\programs\\python\\python38\\libs']
#   INFO: get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#   INFO: customize GnuFCompiler
#   WARN: Could not locate executable g77
#   WARN: Could not locate executable f77
#   INFO: customize IntelVisualFCompiler
#   WARN: Could not locate executable ifort
#   WARN: Could not locate executable ifl
#   INFO: customize AbsoftFCompiler
#   WARN: Could not locate executable f90
#   INFO: customize CompaqVisualFCompiler
#   WARN: Could not locate executable DF
#   INFO: customize IntelItaniumVisualFCompiler
#   WARN: Could not locate executable efl
#   INFO: customize Gnu95FCompiler
#   WARN: Could not locate executable gfortran
#   WARN: Could not locate executable f95
#   INFO: customize G95FCompiler
#   WARN: Could not locate executable g95
#   INFO: customize IntelEM64VisualFCompiler
#   INFO: customize IntelEM64TFCompiler
#   WARN: Could not locate executable efort
#   WARN: Could not locate executable efc
#   INFO: customize PGroupFlangCompiler
#   WARN: Could not locate executable flang
#   WARN: don't know how to compile Fortran code on platform 'nt'
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: accelerate_info:
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: atlas_3_10_blas_threads_info:
#   INFO: Setting PTATLAS=ATLAS
#   INFO:   libraries tatlas not found in ['c:\\users\\user\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\user\\appdata\\local\\programs\\python\\python38\\libs']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: atlas_3_10_blas_info:
#   INFO:   libraries satlas not found in ['c:\\users\\user\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\user\\appdata\\local\\programs\\python\\python38\\libs']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: atlas_blas_threads_info:
#   INFO: Setting PTATLAS=ATLAS
#   INFO:   libraries ptf77blas,ptcblas,atlas not found in ['c:\\users\\user\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\user\\appdata\\local\\programs\\python\\python38\\libs']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: atlas_blas_info:
#   INFO:   libraries f77blas,cblas,atlas not found in ['c:\\users\\user\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\user\\appdata\\local\\programs\\python\\python38\\libs']
#   INFO:   NOT AVAILABLE
#   INFO:
#   c:\users\user\appdata\local\programs\python\python38\lib\site-packages\numpy\distutils\system_info.py:2077: UserWarning:
#       Optimized (vendor) Blas libraries are not found.
#       Falls back to netlib Blas library which has worse performance.
#       A better performance should be easily gained by switching
#       Blas library.
#     if self._calc_info(blas):
#   INFO: blas_info:
#   INFO:   libraries blas not found in ['c:\\users\\user\\appdata\\local\\programs\\python\\python38\\lib', 'C:\\', 'c:\\users\\user\\appdata\\local\\programs\\python\\python38\\libs']
#   INFO:   NOT AVAILABLE
#   INFO:
#   c:\users\user\appdata\local\programs\python\python38\lib\site-packages\numpy\distutils\system_info.py:2077: UserWarning:
#       Blas (http://www.netlib.org/blas/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [blas]) or by setting
#       the BLAS environment variable.
#     if self._calc_info(blas):
#   INFO: blas_src_info:
#   INFO:   NOT AVAILABLE
#   INFO:
#   c:\users\user\appdata\local\programs\python\python38\lib\site-packages\numpy\distutils\system_info.py:2077: UserWarning:
#       Blas (http://www.netlib.org/blas/) sources not found.
#       Directories to search for the sources can be specified in the
#       numpy/distutils/site.cfg file (section [blas_src]) or by setting
#       the BLAS_SRC environment variable.
#     if self._calc_info(blas):
#   INFO:   NOT AVAILABLE
#   INFO:
#   sklearn\setup.py:73: UserWarning:
#       Blas (http://www.netlib.org/blas/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [blas]) or by setting
#       the BLAS environment variable.
#     warnings.warn(BlasNotFoundError.__doc__)
#   running bdist_wheel
#   running build
#   running config_cc
#   INFO: unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#   running config_fc
#   INFO: unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#   running build_src
#   INFO: build_src
#   INFO: building library "libsvm-skl" sources
#   INFO: building library "cblas" sources
#   INFO: building extension "sklearn.__check_build._check_build" sources
#   INFO: building extension "sklearn.cluster._dbscan_inner" sources
#   INFO: building extension "sklearn.cluster._hierarchical" sources
#   INFO: building extension "sklearn.cluster._k_means_elkan" sources
#   INFO: building extension "sklearn.cluster._k_means" sources
#   INFO: building extension "sklearn.datasets._svmlight_format" sources
#   INFO: building extension "sklearn.decomposition._online_lda" sources
#   INFO: building extension "sklearn.decomposition.cdnmf_fast" sources
#   INFO: building extension "sklearn.ensemble._gradient_boosting" sources
#   INFO: building extension "sklearn.feature_extraction._hashing" sources
#   INFO: building extension "sklearn.manifold._utils" sources
#   INFO: building extension "sklearn.manifold._barnes_hut_tsne" sources
#   INFO: building extension "sklearn.metrics.cluster.expected_mutual_info_fast" sources
#   INFO: building extension "sklearn.metrics.pairwise_fast" sources
#   INFO: building extension "sklearn.neighbors.ball_tree" sources
#   INFO: building extension "sklearn.neighbors.kd_tree" sources
#   INFO: building extension "sklearn.neighbors.dist_metrics" sources
#   INFO: building extension "sklearn.neighbors.typedefs" sources
#   INFO: building extension "sklearn.neighbors.quad_tree" sources
#   INFO: building extension "sklearn.tree._tree" sources
#   INFO: building extension "sklearn.tree._splitter" sources
#   INFO: building extension "sklearn.tree._criterion" sources
#   INFO: building extension "sklearn.tree._utils" sources
#   INFO: building extension "sklearn.svm.libsvm" sources
#   INFO: building extension "sklearn.svm.liblinear" sources
#   INFO: building extension "sklearn.svm.libsvm_sparse" sources
#   INFO: building extension "sklearn._isotonic" sources
#   INFO: building extension "sklearn.linear_model.cd_fast" sources
#   INFO: building extension "sklearn.linear_model.sgd_fast" sources
#   INFO: building extension "sklearn.linear_model.sag_fast" sources
#   INFO: building extension "sklearn.utils.sparsefuncs_fast" sources
#   INFO: building extension "sklearn.utils.arrayfuncs" sources
#   INFO: building extension "sklearn.utils.murmurhash" sources
#   INFO: building extension "sklearn.utils.lgamma" sources
#   INFO: building extension "sklearn.utils.graph_shortest_path" sources
#   INFO: building extension "sklearn.utils.fast_dict" sources
#   INFO: building extension "sklearn.utils.seq_dataset" sources
#   INFO: building extension "sklearn.utils.weight_vector" sources
#   INFO: building extension "sklearn.utils._random" sources
#   INFO: building extension "sklearn.utils._logistic_sigmoid" sources
#   INFO: building data_files sources
#   INFO: build_src: building npy-pkg config files
#   c:\users\user\appdata\local\programs\python\python38\lib\site-packages\setuptools\_distutils\cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
#   !!
#
#           ********************************************************************************
#           Please avoid running ``setup.py`` directly.
#           Instead, use pypa/build, pypa/installer or other
#           standards-based tools.
#
#           See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#           ********************************************************************************
#
#   !!
#     self.initialize_options()
#   running build_py
#   creating build
#   creating build\lib.win-amd64-cpython-38
#   creating build\lib.win-amd64-cpython-38\sklearn
#   copying sklearn\base.py -> build\lib.win-amd64-cpython-38\sklearn
#   copying sklearn\calibration.py -> build\lib.win-amd64-cpython-38\sklearn
#   copying sklearn\discriminant_analysis.py -> build\lib.win-amd64-cpython-38\sklearn
#   copying sklearn\dummy.py -> build\lib.win-amd64-cpython-38\sklearn
#   copying sklearn\exceptions.py -> build\lib.win-amd64-cpython-38\sklearn
#   copying sklearn\impute.py -> build\lib.win-amd64-cpython-38\sklearn
#   copying sklearn\isotonic.py -> build\lib.win-amd64-cpython-38\sklearn
#   copying sklearn\kernel_approximation.py -> build\lib.win-amd64-cpython-38\sklearn
#   copying sklearn\kernel_ridge.py -> build\lib.win-amd64-cpython-38\sklearn
#   copying sklearn\multiclass.py -> build\lib.win-amd64-cpython-38\sklearn
#   copying sklearn\multioutput.py -> build\lib.win-amd64-cpython-38\sklearn
#   copying sklearn\naive_bayes.py -> build\lib.win-amd64-cpython-38\sklearn
#   copying sklearn\pipeline.py -> build\lib.win-amd64-cpython-38\sklearn
#   copying sklearn\random_projection.py -> build\lib.win-amd64-cpython-38\sklearn
#   copying sklearn\setup.py -> build\lib.win-amd64-cpython-38\sklearn
#   copying sklearn\_config.py -> build\lib.win-amd64-cpython-38\sklearn
#   copying sklearn\__init__.py -> build\lib.win-amd64-cpython-38\sklearn
#   creating build\lib.win-amd64-cpython-38\sklearn\__check_build
#   copying sklearn\__check_build\setup.py -> build\lib.win-amd64-cpython-38\sklearn\__check_build
#   copying sklearn\__check_build\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\__check_build
#   creating build\lib.win-amd64-cpython-38\sklearn\_build_utils
#   copying sklearn\_build_utils\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\_build_utils
#   creating build\lib.win-amd64-cpython-38\sklearn\compose
#   copying sklearn\compose\_column_transformer.py -> build\lib.win-amd64-cpython-38\sklearn\compose
#   copying sklearn\compose\_target.py -> build\lib.win-amd64-cpython-38\sklearn\compose
#   copying sklearn\compose\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\compose
#   creating build\lib.win-amd64-cpython-38\sklearn\compose\tests
#   copying sklearn\compose\tests\test_column_transformer.py -> build\lib.win-amd64-cpython-38\sklearn\compose/tests
#   copying sklearn\compose\tests\test_target.py -> build\lib.win-amd64-cpython-38\sklearn\compose/tests
#   copying sklearn\compose\tests\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\compose/tests
#   creating build\lib.win-amd64-cpython-38\sklearn\covariance
#   copying sklearn\covariance\elliptic_envelope.py -> build\lib.win-amd64-cpython-38\sklearn\covariance
#   copying sklearn\covariance\empirical_covariance_.py -> build\lib.win-amd64-cpython-38\sklearn\covariance
#   copying sklearn\covariance\graph_lasso_.py -> build\lib.win-amd64-cpython-38\sklearn\covariance
#   copying sklearn\covariance\robust_covariance.py -> build\lib.win-amd64-cpython-38\sklearn\covariance
#   copying sklearn\covariance\shrunk_covariance_.py -> build\lib.win-amd64-cpython-38\sklearn\covariance
#   copying sklearn\covariance\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\covariance
#   creating build\lib.win-amd64-cpython-38\sklearn\covariance\tests
#   copying sklearn\covariance\tests\test_covariance.py -> build\lib.win-amd64-cpython-38\sklearn\covariance/tests
#   copying sklearn\covariance\tests\test_elliptic_envelope.py -> build\lib.win-amd64-cpython-38\sklearn\covariance/tests
#   copying sklearn\covariance\tests\test_graphical_lasso.py -> build\lib.win-amd64-cpython-38\sklearn\covariance/tests
#   copying sklearn\covariance\tests\test_graph_lasso.py -> build\lib.win-amd64-cpython-38\sklearn\covariance/tests
#   copying sklearn\covariance\tests\test_robust_covariance.py -> build\lib.win-amd64-cpython-38\sklearn\covariance/tests
#   copying sklearn\covariance\tests\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\covariance/tests
#   creating build\lib.win-amd64-cpython-38\sklearn\cross_decomposition
#   copying sklearn\cross_decomposition\cca_.py -> build\lib.win-amd64-cpython-38\sklearn\cross_decomposition
#   copying sklearn\cross_decomposition\pls_.py -> build\lib.win-amd64-cpython-38\sklearn\cross_decomposition
#   copying sklearn\cross_decomposition\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\cross_decomposition
#   creating build\lib.win-amd64-cpython-38\sklearn\cross_decomposition\tests
#   copying sklearn\cross_decomposition\tests\test_pls.py -> build\lib.win-amd64-cpython-38\sklearn\cross_decomposition/tests
#   copying sklearn\cross_decomposition\tests\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\cross_decomposition/tests
#   creating build\lib.win-amd64-cpython-38\sklearn\feature_selection
#   copying sklearn\feature_selection\base.py -> build\lib.win-amd64-cpython-38\sklearn\feature_selection
#   copying sklearn\feature_selection\from_model.py -> build\lib.win-amd64-cpython-38\sklearn\feature_selection
#   copying sklearn\feature_selection\mutual_info_.py -> build\lib.win-amd64-cpython-38\sklearn\feature_selection
#   copying sklearn\feature_selection\rfe.py -> build\lib.win-amd64-cpython-38\sklearn\feature_selection
#   copying sklearn\feature_selection\univariate_selection.py -> build\lib.win-amd64-cpython-38\sklearn\feature_selection
#   copying sklearn\feature_selection\variance_threshold.py -> build\lib.win-amd64-cpython-38\sklearn\feature_selection
#   copying sklearn\feature_selection\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\feature_selection
#   creating build\lib.win-amd64-cpython-38\sklearn\feature_selection\tests
#   copying sklearn\feature_selection\tests\test_base.py -> build\lib.win-amd64-cpython-38\sklearn\feature_selection/tests
#   copying sklearn\feature_selection\tests\test_chi2.py -> build\lib.win-amd64-cpython-38\sklearn\feature_selection/tests
#   copying sklearn\feature_selection\tests\test_feature_select.py -> build\lib.win-amd64-cpython-38\sklearn\feature_selection/tests
#   copying sklearn\feature_selection\tests\test_from_model.py -> build\lib.win-amd64-cpython-38\sklearn\feature_selection/tests
#   copying sklearn\feature_selection\tests\test_mutual_info.py -> build\lib.win-amd64-cpython-38\sklearn\feature_selection/tests
#   copying sklearn\feature_selection\tests\test_rfe.py -> build\lib.win-amd64-cpython-38\sklearn\feature_selection/tests
#   copying sklearn\feature_selection\tests\test_variance_threshold.py -> build\lib.win-amd64-cpython-38\sklearn\feature_selection/tests
#   copying sklearn\feature_selection\tests\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\feature_selection/tests
#   creating build\lib.win-amd64-cpython-38\sklearn\gaussian_process
#   copying sklearn\gaussian_process\correlation_models.py -> build\lib.win-amd64-cpython-38\sklearn\gaussian_process
#   copying sklearn\gaussian_process\gpc.py -> build\lib.win-amd64-cpython-38\sklearn\gaussian_process
#   copying sklearn\gaussian_process\gpr.py -> build\lib.win-amd64-cpython-38\sklearn\gaussian_process
#   copying sklearn\gaussian_process\kernels.py -> build\lib.win-amd64-cpython-38\sklearn\gaussian_process
#   copying sklearn\gaussian_process\regression_models.py -> build\lib.win-amd64-cpython-38\sklearn\gaussian_process
#   copying sklearn\gaussian_process\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\gaussian_process
#   creating build\lib.win-amd64-cpython-38\sklearn\gaussian_process\tests
#   copying sklearn\gaussian_process\tests\test_gpc.py -> build\lib.win-amd64-cpython-38\sklearn\gaussian_process/tests
#   copying sklearn\gaussian_process\tests\test_gpr.py -> build\lib.win-amd64-cpython-38\sklearn\gaussian_process/tests
#   copying sklearn\gaussian_process\tests\test_kernels.py -> build\lib.win-amd64-cpython-38\sklearn\gaussian_process/tests
#   copying sklearn\gaussian_process\tests\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\gaussian_process/tests
#   creating build\lib.win-amd64-cpython-38\sklearn\mixture
#   copying sklearn\mixture\base.py -> build\lib.win-amd64-cpython-38\sklearn\mixture
#   copying sklearn\mixture\bayesian_mixture.py -> build\lib.win-amd64-cpython-38\sklearn\mixture
#   copying sklearn\mixture\gaussian_mixture.py -> build\lib.win-amd64-cpython-38\sklearn\mixture
#   copying sklearn\mixture\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\mixture
#   creating build\lib.win-amd64-cpython-38\sklearn\mixture\tests
#   copying sklearn\mixture\tests\test_bayesian_mixture.py -> build\lib.win-amd64-cpython-38\sklearn\mixture/tests
#   copying sklearn\mixture\tests\test_gaussian_mixture.py -> build\lib.win-amd64-cpython-38\sklearn\mixture/tests
#   copying sklearn\mixture\tests\test_mixture.py -> build\lib.win-amd64-cpython-38\sklearn\mixture/tests
#   copying sklearn\mixture\tests\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\mixture/tests
#   creating build\lib.win-amd64-cpython-38\sklearn\model_selection
#   copying sklearn\model_selection\_search.py -> build\lib.win-amd64-cpython-38\sklearn\model_selection
#   copying sklearn\model_selection\_split.py -> build\lib.win-amd64-cpython-38\sklearn\model_selection
#   copying sklearn\model_selection\_validation.py -> build\lib.win-amd64-cpython-38\sklearn\model_selection
#   copying sklearn\model_selection\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\model_selection
#   creating build\lib.win-amd64-cpython-38\sklearn\model_selection\tests
#   copying sklearn\model_selection\tests\common.py -> build\lib.win-amd64-cpython-38\sklearn\model_selection/tests
#   copying sklearn\model_selection\tests\test_search.py -> build\lib.win-amd64-cpython-38\sklearn\model_selection/tests
#   copying sklearn\model_selection\tests\test_split.py -> build\lib.win-amd64-cpython-38\sklearn\model_selection/tests
#   copying sklearn\model_selection\tests\test_validation.py -> build\lib.win-amd64-cpython-38\sklearn\model_selection/tests
#   copying sklearn\model_selection\tests\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\model_selection/tests
#   creating build\lib.win-amd64-cpython-38\sklearn\neural_network
#   copying sklearn\neural_network\multilayer_perceptron.py -> build\lib.win-amd64-cpython-38\sklearn\neural_network
#   copying sklearn\neural_network\rbm.py -> build\lib.win-amd64-cpython-38\sklearn\neural_network
#   copying sklearn\neural_network\_base.py -> build\lib.win-amd64-cpython-38\sklearn\neural_network
#   copying sklearn\neural_network\_stochastic_optimizers.py -> build\lib.win-amd64-cpython-38\sklearn\neural_network
#   copying sklearn\neural_network\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\neural_network
#   creating build\lib.win-amd64-cpython-38\sklearn\neural_network\tests
#   copying sklearn\neural_network\tests\test_mlp.py -> build\lib.win-amd64-cpython-38\sklearn\neural_network/tests
#   copying sklearn\neural_network\tests\test_rbm.py -> build\lib.win-amd64-cpython-38\sklearn\neural_network/tests
#   copying sklearn\neural_network\tests\test_stochastic_optimizers.py -> build\lib.win-amd64-cpython-38\sklearn\neural_network/tests
#   copying sklearn\neural_network\tests\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\neural_network/tests
#   creating build\lib.win-amd64-cpython-38\sklearn\preprocessing
#   copying sklearn\preprocessing\base.py -> build\lib.win-amd64-cpython-38\sklearn\preprocessing
#   copying sklearn\preprocessing\data.py -> build\lib.win-amd64-cpython-38\sklearn\preprocessing
#   copying sklearn\preprocessing\imputation.py -> build\lib.win-amd64-cpython-38\sklearn\preprocessing
#   copying sklearn\preprocessing\label.py -> build\lib.win-amd64-cpython-38\sklearn\preprocessing
#   copying sklearn\preprocessing\_discretization.py -> build\lib.win-amd64-cpython-38\sklearn\preprocessing
#   copying sklearn\preprocessing\_encoders.py -> build\lib.win-amd64-cpython-38\sklearn\preprocessing
#   copying sklearn\preprocessing\_function_transformer.py -> build\lib.win-amd64-cpython-38\sklearn\preprocessing
#   copying sklearn\preprocessing\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\preprocessing
#   creating build\lib.win-amd64-cpython-38\sklearn\preprocessing\tests
#   copying sklearn\preprocessing\tests\test_base.py -> build\lib.win-amd64-cpython-38\sklearn\preprocessing/tests
#   copying sklearn\preprocessing\tests\test_common.py -> build\lib.win-amd64-cpython-38\sklearn\preprocessing/tests
#   copying sklearn\preprocessing\tests\test_data.py -> build\lib.win-amd64-cpython-38\sklearn\preprocessing/tests
#   copying sklearn\preprocessing\tests\test_discretization.py -> build\lib.win-amd64-cpython-38\sklearn\preprocessing/tests
#   copying sklearn\preprocessing\tests\test_encoders.py -> build\lib.win-amd64-cpython-38\sklearn\preprocessing/tests
#   copying sklearn\preprocessing\tests\test_function_transformer.py -> build\lib.win-amd64-cpython-38\sklearn\preprocessing/tests
#   copying sklearn\preprocessing\tests\test_imputation.py -> build\lib.win-amd64-cpython-38\sklearn\preprocessing/tests
#   copying sklearn\preprocessing\tests\test_label.py -> build\lib.win-amd64-cpython-38\sklearn\preprocessing/tests
#   copying sklearn\preprocessing\tests\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\preprocessing/tests
#   creating build\lib.win-amd64-cpython-38\sklearn\semi_supervised
#   copying sklearn\semi_supervised\label_propagation.py -> build\lib.win-amd64-cpython-38\sklearn\semi_supervised
#   copying sklearn\semi_supervised\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\semi_supervised
#   creating build\lib.win-amd64-cpython-38\sklearn\semi_supervised\tests
#   copying sklearn\semi_supervised\tests\test_label_propagation.py -> build\lib.win-amd64-cpython-38\sklearn\semi_supervised/tests
#   copying sklearn\semi_supervised\tests\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\semi_supervised/tests
#   creating build\lib.win-amd64-cpython-38\sklearn\cluster
#   copying sklearn\cluster\affinity_propagation_.py -> build\lib.win-amd64-cpython-38\sklearn\cluster
#   copying sklearn\cluster\bicluster.py -> build\lib.win-amd64-cpython-38\sklearn\cluster
#   copying sklearn\cluster\birch.py -> build\lib.win-amd64-cpython-38\sklearn\cluster
#   copying sklearn\cluster\dbscan_.py -> build\lib.win-amd64-cpython-38\sklearn\cluster
#   copying sklearn\cluster\hierarchical.py -> build\lib.win-amd64-cpython-38\sklearn\cluster
#   copying sklearn\cluster\k_means_.py -> build\lib.win-amd64-cpython-38\sklearn\cluster
#   copying sklearn\cluster\mean_shift_.py -> build\lib.win-amd64-cpython-38\sklearn\cluster
#   copying sklearn\cluster\setup.py -> build\lib.win-amd64-cpython-38\sklearn\cluster
#   copying sklearn\cluster\spectral.py -> build\lib.win-amd64-cpython-38\sklearn\cluster
#   copying sklearn\cluster\_feature_agglomeration.py -> build\lib.win-amd64-cpython-38\sklearn\cluster
#   copying sklearn\cluster\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\cluster
#   creating build\lib.win-amd64-cpython-38\sklearn\cluster\tests
#   copying sklearn\cluster\tests\common.py -> build\lib.win-amd64-cpython-38\sklearn\cluster\tests
#   copying sklearn\cluster\tests\test_affinity_propagation.py -> build\lib.win-amd64-cpython-38\sklearn\cluster\tests
#   copying sklearn\cluster\tests\test_bicluster.py -> build\lib.win-amd64-cpython-38\sklearn\cluster\tests
#   copying sklearn\cluster\tests\test_birch.py -> build\lib.win-amd64-cpython-38\sklearn\cluster\tests
#   copying sklearn\cluster\tests\test_dbscan.py -> build\lib.win-amd64-cpython-38\sklearn\cluster\tests
#   copying sklearn\cluster\tests\test_feature_agglomeration.py -> build\lib.win-amd64-cpython-38\sklearn\cluster\tests
#   copying sklearn\cluster\tests\test_hierarchical.py -> build\lib.win-amd64-cpython-38\sklearn\cluster\tests
#   copying sklearn\cluster\tests\test_k_means.py -> build\lib.win-amd64-cpython-38\sklearn\cluster\tests
#   copying sklearn\cluster\tests\test_mean_shift.py -> build\lib.win-amd64-cpython-38\sklearn\cluster\tests
#   copying sklearn\cluster\tests\test_spectral.py -> build\lib.win-amd64-cpython-38\sklearn\cluster\tests
#   copying sklearn\cluster\tests\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\cluster\tests
#   creating build\lib.win-amd64-cpython-38\sklearn\datasets
#   copying sklearn\datasets\base.py -> build\lib.win-amd64-cpython-38\sklearn\datasets
#   copying sklearn\datasets\california_housing.py -> build\lib.win-amd64-cpython-38\sklearn\datasets
#   copying sklearn\datasets\covtype.py -> build\lib.win-amd64-cpython-38\sklearn\datasets
#   copying sklearn\datasets\kddcup99.py -> build\lib.win-amd64-cpython-38\sklearn\datasets
#   copying sklearn\datasets\lfw.py -> build\lib.win-amd64-cpython-38\sklearn\datasets
#   copying sklearn\datasets\mlcomp.py -> build\lib.win-amd64-cpython-38\sklearn\datasets
#   copying sklearn\datasets\mldata.py -> build\lib.win-amd64-cpython-38\sklearn\datasets
#   copying sklearn\datasets\olivetti_faces.py -> build\lib.win-amd64-cpython-38\sklearn\datasets
#   copying sklearn\datasets\openml.py -> build\lib.win-amd64-cpython-38\sklearn\datasets
#   copying sklearn\datasets\rcv1.py -> build\lib.win-amd64-cpython-38\sklearn\datasets
#   copying sklearn\datasets\samples_generator.py -> build\lib.win-amd64-cpython-38\sklearn\datasets
#   copying sklearn\datasets\setup.py -> build\lib.win-amd64-cpython-38\sklearn\datasets
#   copying sklearn\datasets\species_distributions.py -> build\lib.win-amd64-cpython-38\sklearn\datasets
#   copying sklearn\datasets\svmlight_format.py -> build\lib.win-amd64-cpython-38\sklearn\datasets
#   copying sklearn\datasets\twenty_newsgroups.py -> build\lib.win-amd64-cpython-38\sklearn\datasets
#   copying sklearn\datasets\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\datasets
#   creating build\lib.win-amd64-cpython-38\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_20news.py -> build\lib.win-amd64-cpython-38\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_base.py -> build\lib.win-amd64-cpython-38\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_california_housing.py -> build\lib.win-amd64-cpython-38\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_common.py -> build\lib.win-amd64-cpython-38\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_covtype.py -> build\lib.win-amd64-cpython-38\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_kddcup99.py -> build\lib.win-amd64-cpython-38\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_lfw.py -> build\lib.win-amd64-cpython-38\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_mldata.py -> build\lib.win-amd64-cpython-38\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_openml.py -> build\lib.win-amd64-cpython-38\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_rcv1.py -> build\lib.win-amd64-cpython-38\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_samples_generator.py -> build\lib.win-amd64-cpython-38\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_svmlight_format.py -> build\lib.win-amd64-cpython-38\sklearn\datasets\tests
#   copying sklearn\datasets\tests\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\datasets\tests
#   creating build\lib.win-amd64-cpython-38\sklearn\decomposition
#   copying sklearn\decomposition\base.py -> build\lib.win-amd64-cpython-38\sklearn\decomposition
#   copying sklearn\decomposition\dict_learning.py -> build\lib.win-amd64-cpython-38\sklearn\decomposition
#   copying sklearn\decomposition\factor_analysis.py -> build\lib.win-amd64-cpython-38\sklearn\decomposition
#   copying sklearn\decomposition\fastica_.py -> build\lib.win-amd64-cpython-38\sklearn\decomposition
#   copying sklearn\decomposition\incremental_pca.py -> build\lib.win-amd64-cpython-38\sklearn\decomposition
#   copying sklearn\decomposition\kernel_pca.py -> build\lib.win-amd64-cpython-38\sklearn\decomposition
#   copying sklearn\decomposition\nmf.py -> build\lib.win-amd64-cpython-38\sklearn\decomposition
#   copying sklearn\decomposition\online_lda.py -> build\lib.win-amd64-cpython-38\sklearn\decomposition
#   copying sklearn\decomposition\pca.py -> build\lib.win-amd64-cpython-38\sklearn\decomposition
#   copying sklearn\decomposition\setup.py -> build\lib.win-amd64-cpython-38\sklearn\decomposition
#   copying sklearn\decomposition\sparse_pca.py -> build\lib.win-amd64-cpython-38\sklearn\decomposition
#   copying sklearn\decomposition\truncated_svd.py -> build\lib.win-amd64-cpython-38\sklearn\decomposition
#   copying sklearn\decomposition\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\decomposition
#   creating build\lib.win-amd64-cpython-38\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_dict_learning.py -> build\lib.win-amd64-cpython-38\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_factor_analysis.py -> build\lib.win-amd64-cpython-38\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_fastica.py -> build\lib.win-amd64-cpython-38\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_incremental_pca.py -> build\lib.win-amd64-cpython-38\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_kernel_pca.py -> build\lib.win-amd64-cpython-38\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_nmf.py -> build\lib.win-amd64-cpython-38\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_online_lda.py -> build\lib.win-amd64-cpython-38\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_pca.py -> build\lib.win-amd64-cpython-38\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_sparse_pca.py -> build\lib.win-amd64-cpython-38\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_truncated_svd.py -> build\lib.win-amd64-cpython-38\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\decomposition\tests
#   creating build\lib.win-amd64-cpython-38\sklearn\ensemble
#   copying sklearn\ensemble\bagging.py -> build\lib.win-amd64-cpython-38\sklearn\ensemble
#   copying sklearn\ensemble\base.py -> build\lib.win-amd64-cpython-38\sklearn\ensemble
#   copying sklearn\ensemble\forest.py -> build\lib.win-amd64-cpython-38\sklearn\ensemble
#   copying sklearn\ensemble\gradient_boosting.py -> build\lib.win-amd64-cpython-38\sklearn\ensemble
#   copying sklearn\ensemble\iforest.py -> build\lib.win-amd64-cpython-38\sklearn\ensemble
#   copying sklearn\ensemble\partial_dependence.py -> build\lib.win-amd64-cpython-38\sklearn\ensemble
#   copying sklearn\ensemble\setup.py -> build\lib.win-amd64-cpython-38\sklearn\ensemble
#   copying sklearn\ensemble\voting_classifier.py -> build\lib.win-amd64-cpython-38\sklearn\ensemble
#   copying sklearn\ensemble\weight_boosting.py -> build\lib.win-amd64-cpython-38\sklearn\ensemble
#   copying sklearn\ensemble\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\ensemble
#   creating build\lib.win-amd64-cpython-38\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\test_bagging.py -> build\lib.win-amd64-cpython-38\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\test_base.py -> build\lib.win-amd64-cpython-38\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\test_forest.py -> build\lib.win-amd64-cpython-38\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\test_gradient_boosting.py -> build\lib.win-amd64-cpython-38\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\test_gradient_boosting_loss_functions.py -> build\lib.win-amd64-cpython-38\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\test_iforest.py -> build\lib.win-amd64-cpython-38\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\test_partial_dependence.py -> build\lib.win-amd64-cpython-38\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\test_voting_classifier.py -> build\lib.win-amd64-cpython-38\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\test_weight_boosting.py -> build\lib.win-amd64-cpython-38\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\ensemble\tests
#   creating build\lib.win-amd64-cpython-38\sklearn\externals
#   copying sklearn\externals\conftest.py -> build\lib.win-amd64-cpython-38\sklearn\externals
#   copying sklearn\externals\funcsigs.py -> build\lib.win-amd64-cpython-38\sklearn\externals
#   copying sklearn\externals\setup.py -> build\lib.win-amd64-cpython-38\sklearn\externals
#   copying sklearn\externals\six.py -> build\lib.win-amd64-cpython-38\sklearn\externals
#   copying sklearn\externals\_arff.py -> build\lib.win-amd64-cpython-38\sklearn\externals
#   copying sklearn\externals\_pilutil.py -> build\lib.win-amd64-cpython-38\sklearn\externals
#   copying sklearn\externals\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\externals
#   creating build\lib.win-amd64-cpython-38\sklearn\externals\joblib
#   copying sklearn\externals\joblib\backports.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib
#   copying sklearn\externals\joblib\compressor.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib
#   copying sklearn\externals\joblib\disk.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib
#   copying sklearn\externals\joblib\executor.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib
#   copying sklearn\externals\joblib\format_stack.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib
#   copying sklearn\externals\joblib\func_inspect.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib
#   copying sklearn\externals\joblib\hashing.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib
#   copying sklearn\externals\joblib\logger.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib
#   copying sklearn\externals\joblib\memory.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib
#   copying sklearn\externals\joblib\my_exceptions.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib
#   copying sklearn\externals\joblib\numpy_pickle.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib
#   copying sklearn\externals\joblib\numpy_pickle_compat.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib
#   copying sklearn\externals\joblib\numpy_pickle_utils.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib
#   copying sklearn\externals\joblib\parallel.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib
#   copying sklearn\externals\joblib\pool.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib
#   copying sklearn\externals\joblib\testing.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib
#   copying sklearn\externals\joblib\_compat.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib
#   copying sklearn\externals\joblib\_dask.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib
#   copying sklearn\externals\joblib\_memmapping_reducer.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib
#   copying sklearn\externals\joblib\_memory_helpers.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib
#   copying sklearn\externals\joblib\_multiprocessing_helpers.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib
#   copying sklearn\externals\joblib\_parallel_backends.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib
#   copying sklearn\externals\joblib\_store_backends.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib
#   copying sklearn\externals\joblib\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib
#   creating build\lib.win-amd64-cpython-38\sklearn\externals\joblib\externals
#   copying sklearn\externals\joblib\externals\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib/externals
#   creating build\lib.win-amd64-cpython-38\sklearn\externals\joblib\externals\loky
#   copying sklearn\externals\joblib\externals\loky\cloudpickle_wrapper.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib/externals/loky
#   copying sklearn\externals\joblib\externals\loky\process_executor.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib/externals/loky
#   copying sklearn\externals\joblib\externals\loky\reusable_executor.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib/externals/loky
#   copying sklearn\externals\joblib\externals\loky\_base.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib/externals/loky
#   copying sklearn\externals\joblib\externals\loky\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib/externals/loky
#   creating build\lib.win-amd64-cpython-38\sklearn\externals\joblib\externals\loky\backend
#   copying sklearn\externals\joblib\externals\loky\backend\compat.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\compat_posix.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\compat_win32.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\context.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\fork_exec.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\managers.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\popen_loky_posix.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\popen_loky_win32.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\process.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\queues.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\reduction.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\semaphore_tracker.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\semlock.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\spawn.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\synchronize.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\utils.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\_posix_reduction.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\_posix_wait.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\_win_reduction.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\_win_wait.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib/externals/loky/backend
#   creating build\lib.win-amd64-cpython-38\sklearn\externals\joblib\externals\cloudpickle
#   copying sklearn\externals\joblib\externals\cloudpickle\cloudpickle.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib/externals/cloudpickle
#   copying sklearn\externals\joblib\externals\cloudpickle\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\externals\joblib/externals/cloudpickle
#   creating build\lib.win-amd64-cpython-38\sklearn\feature_extraction
#   copying sklearn\feature_extraction\dict_vectorizer.py -> build\lib.win-amd64-cpython-38\sklearn\feature_extraction
#   copying sklearn\feature_extraction\hashing.py -> build\lib.win-amd64-cpython-38\sklearn\feature_extraction
#   copying sklearn\feature_extraction\image.py -> build\lib.win-amd64-cpython-38\sklearn\feature_extraction
#   copying sklearn\feature_extraction\setup.py -> build\lib.win-amd64-cpython-38\sklearn\feature_extraction
#   copying sklearn\feature_extraction\stop_words.py -> build\lib.win-amd64-cpython-38\sklearn\feature_extraction
#   copying sklearn\feature_extraction\text.py -> build\lib.win-amd64-cpython-38\sklearn\feature_extraction
#   copying sklearn\feature_extraction\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\feature_extraction
#   creating build\lib.win-amd64-cpython-38\sklearn\feature_extraction\tests
#   copying sklearn\feature_extraction\tests\test_dict_vectorizer.py -> build\lib.win-amd64-cpython-38\sklearn\feature_extraction\tests
#   copying sklearn\feature_extraction\tests\test_feature_hasher.py -> build\lib.win-amd64-cpython-38\sklearn\feature_extraction\tests
#   copying sklearn\feature_extraction\tests\test_image.py -> build\lib.win-amd64-cpython-38\sklearn\feature_extraction\tests
#   copying sklearn\feature_extraction\tests\test_text.py -> build\lib.win-amd64-cpython-38\sklearn\feature_extraction\tests
#   copying sklearn\feature_extraction\tests\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\feature_extraction\tests
#   creating build\lib.win-amd64-cpython-38\sklearn\manifold
#   copying sklearn\manifold\isomap.py -> build\lib.win-amd64-cpython-38\sklearn\manifold
#   copying sklearn\manifold\locally_linear.py -> build\lib.win-amd64-cpython-38\sklearn\manifold
#   copying sklearn\manifold\mds.py -> build\lib.win-amd64-cpython-38\sklearn\manifold
#   copying sklearn\manifold\setup.py -> build\lib.win-amd64-cpython-38\sklearn\manifold
#   copying sklearn\manifold\spectral_embedding_.py -> build\lib.win-amd64-cpython-38\sklearn\manifold
#   copying sklearn\manifold\t_sne.py -> build\lib.win-amd64-cpython-38\sklearn\manifold
#   copying sklearn\manifold\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\manifold
#   creating build\lib.win-amd64-cpython-38\sklearn\manifold\tests
#   copying sklearn\manifold\tests\test_isomap.py -> build\lib.win-amd64-cpython-38\sklearn\manifold\tests
#   copying sklearn\manifold\tests\test_locally_linear.py -> build\lib.win-amd64-cpython-38\sklearn\manifold\tests
#   copying sklearn\manifold\tests\test_mds.py -> build\lib.win-amd64-cpython-38\sklearn\manifold\tests
#   copying sklearn\manifold\tests\test_spectral_embedding.py -> build\lib.win-amd64-cpython-38\sklearn\manifold\tests
#   copying sklearn\manifold\tests\test_t_sne.py -> build\lib.win-amd64-cpython-38\sklearn\manifold\tests
#   copying sklearn\manifold\tests\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\manifold\tests
#   creating build\lib.win-amd64-cpython-38\sklearn\metrics
#   copying sklearn\metrics\base.py -> build\lib.win-amd64-cpython-38\sklearn\metrics
#   copying sklearn\metrics\classification.py -> build\lib.win-amd64-cpython-38\sklearn\metrics
#   copying sklearn\metrics\pairwise.py -> build\lib.win-amd64-cpython-38\sklearn\metrics
#   copying sklearn\metrics\ranking.py -> build\lib.win-amd64-cpython-38\sklearn\metrics
# ...
#   copying sklearn\metrics\tests\test_ranking.py -> build\lib.win-amd64-cpython-38\sklearn\metrics\tests
#   copying sklearn\metrics\tests\test_regression.py -> build\lib.win-amd64-cpython-38\sklearn\metrics\tests
#   copying sklearn\metrics\tests\test_score_objects.py -> build\lib.win-amd64-cpython-38\sklearn\metrics\tests
#   copying sklearn\metrics\tests\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\metrics\tests
#   creating build\lib.win-amd64-cpython-38\sklearn\neighbors
#   copying sklearn\neighbors\approximate.py -> build\lib.win-amd64-cpython-38\sklearn\neighbors
#   copying sklearn\neighbors\base.py -> build\lib.win-amd64-cpython-38\sklearn\neighbors
#   copying sklearn\neighbors\classification.py -> build\lib.win-amd64-cpython-38\sklearn\neighbors
#   copying sklearn\neighbors\graph.py -> build\lib.win-amd64-cpython-38\sklearn\neighbors
#   copying sklearn\neighbors\kde.py -> build\lib.win-amd64-cpython-38\sklearn\neighbors
#   copying sklearn\neighbors\lof.py -> build\lib.win-amd64-cpython-38\sklearn\neighbors
#   copying sklearn\neighbors\nearest_centroid.py -> build\lib.win-amd64-cpython-38\sklearn\neighbors
#   copying sklearn\neighbors\regression.py -> build\lib.win-amd64-cpython-38\sklearn\neighbors
#   copying sklearn\neighbors\setup.py -> build\lib.win-amd64-cpython-38\sklearn\neighbors
#   copying sklearn\neighbors\unsupervised.py -> build\lib.win-amd64-cpython-38\sklearn\neighbors
#   copying sklearn\neighbors\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\neighbors
#   creating build\lib.win-amd64-cpython-38\sklearn\neighbors\tests
#   copying sklearn\neighbors\tests\test_approximate.py -> build\lib.win-amd64-cpython-38\sklearn\neighbors\tests
#   copying sklearn\neighbors\tests\test_ball_tree.py -> build\lib.win-amd64-cpython-38\sklearn\neighbors\tests
#   copying sklearn\neighbors\tests\test_dist_metrics.py -> build\lib.win-amd64-cpython-38\sklearn\neighbors\tests
#   copying sklearn\neighbors\tests\test_kde.py -> build\lib.win-amd64-cpython-38\sklearn\neighbors\tests
#   copying sklearn\neighbors\tests\test_kd_tree.py -> build\lib.win-amd64-cpython-38\sklearn\neighbors\tests
#   copying sklearn\neighbors\tests\test_lof.py -> build\lib.win-amd64-cpython-38\sklearn\neighbors\tests
#   copying sklearn\neighbors\tests\test_nearest_centroid.py -> build\lib.win-amd64-cpython-38\sklearn\neighbors\tests
#   copying sklearn\neighbors\tests\test_neighbors.py -> build\lib.win-amd64-cpython-38\sklearn\neighbors\tests
#   copying sklearn\neighbors\tests\test_quad_tree.py -> build\lib.win-amd64-cpython-38\sklearn\neighbors\tests
#   copying sklearn\neighbors\tests\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\neighbors\tests
#   creating build\lib.win-amd64-cpython-38\sklearn\tree
#   copying sklearn\tree\export.py -> build\lib.win-amd64-cpython-38\sklearn\tree
#   copying sklearn\tree\setup.py -> build\lib.win-amd64-cpython-38\sklearn\tree
#   copying sklearn\tree\tree.py -> build\lib.win-amd64-cpython-38\sklearn\tree
#   copying sklearn\tree\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\tree
#   creating build\lib.win-amd64-cpython-38\sklearn\tree\tests
#   copying sklearn\tree\tests\test_export.py -> build\lib.win-amd64-cpython-38\sklearn\tree\tests
#   copying sklearn\tree\tests\test_tree.py -> build\lib.win-amd64-cpython-38\sklearn\tree\tests
#   copying sklearn\tree\tests\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\tree\tests
#   creating build\lib.win-amd64-cpython-38\sklearn\svm
#   copying sklearn\svm\base.py -> build\lib.win-amd64-cpython-38\sklearn\svm
#   copying sklearn\svm\bounds.py -> build\lib.win-amd64-cpython-38\sklearn\svm
#   copying sklearn\svm\classes.py -> build\lib.win-amd64-cpython-38\sklearn\svm
#   copying sklearn\svm\setup.py -> build\lib.win-amd64-cpython-38\sklearn\svm
#   copying sklearn\svm\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\svm
#   creating build\lib.win-amd64-cpython-38\sklearn\svm\tests
#   copying sklearn\svm\tests\test_bounds.py -> build\lib.win-amd64-cpython-38\sklearn\svm\tests
#   copying sklearn\svm\tests\test_sparse.py -> build\lib.win-amd64-cpython-38\sklearn\svm\tests
#   copying sklearn\svm\tests\test_svm.py -> build\lib.win-amd64-cpython-38\sklearn\svm\tests
#   copying sklearn\svm\tests\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\svm\tests
#   creating build\lib.win-amd64-cpython-38\sklearn\linear_model
#   copying sklearn\linear_model\base.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model
#   copying sklearn\linear_model\bayes.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model
#   copying sklearn\linear_model\coordinate_descent.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model
#   copying sklearn\linear_model\huber.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model
#   copying sklearn\linear_model\least_angle.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model
#   copying sklearn\linear_model\logistic.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model
#   copying sklearn\linear_model\omp.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model
#   copying sklearn\linear_model\passive_aggressive.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model
#   copying sklearn\linear_model\perceptron.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model
#   copying sklearn\linear_model\randomized_l1.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model
#   copying sklearn\linear_model\ransac.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model
#   copying sklearn\linear_model\ridge.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model
#   copying sklearn\linear_model\sag.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model
#   copying sklearn\linear_model\setup.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model
#   copying sklearn\linear_model\stochastic_gradient.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model
#   copying sklearn\linear_model\theil_sen.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model
#   copying sklearn\linear_model\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model
#   creating build\lib.win-amd64-cpython-38\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_base.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_bayes.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_coordinate_descent.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_huber.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_least_angle.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_logistic.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_omp.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_passive_aggressive.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_perceptron.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_randomized_l1.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_ransac.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_ridge.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_sag.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_sgd.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_sparse_coordinate_descent.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_theil_sen.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\linear_model\tests
#   creating build\lib.win-amd64-cpython-38\sklearn\utils
#   copying sklearn\utils\arpack.py -> build\lib.win-amd64-cpython-38\sklearn\utils
#   copying sklearn\utils\bench.py -> build\lib.win-amd64-cpython-38\sklearn\utils
#   copying sklearn\utils\class_weight.py -> build\lib.win-amd64-cpython-38\sklearn\utils
#   copying sklearn\utils\deprecation.py -> build\lib.win-amd64-cpython-38\sklearn\utils
#   copying sklearn\utils\estimator_checks.py -> build\lib.win-amd64-cpython-38\sklearn\utils
#   copying sklearn\utils\extmath.py -> build\lib.win-amd64-cpython-38\sklearn\utils
#   copying sklearn\utils\fixes.py -> build\lib.win-amd64-cpython-38\sklearn\utils
#   copying sklearn\utils\graph.py -> build\lib.win-amd64-cpython-38\sklearn\utils
#   copying sklearn\utils\linear_assignment_.py -> build\lib.win-amd64-cpython-38\sklearn\utils
#   copying sklearn\utils\metaestimators.py -> build\lib.win-amd64-cpython-38\sklearn\utils
#   copying sklearn\utils\mocking.py -> build\lib.win-amd64-cpython-38\sklearn\utils
#   copying sklearn\utils\multiclass.py -> build\lib.win-amd64-cpython-38\sklearn\utils
#   copying sklearn\utils\optimize.py -> build\lib.win-amd64-cpython-38\sklearn\utils
#   copying sklearn\utils\random.py -> build\lib.win-amd64-cpython-38\sklearn\utils
#   copying sklearn\utils\setup.py -> build\lib.win-amd64-cpython-38\sklearn\utils
#   copying sklearn\utils\sparsefuncs.py -> build\lib.win-amd64-cpython-38\sklearn\utils
#   copying sklearn\utils\stats.py -> build\lib.win-amd64-cpython-38\sklearn\utils
#   copying sklearn\utils\testing.py -> build\lib.win-amd64-cpython-38\sklearn\utils
#   copying sklearn\utils\validation.py -> build\lib.win-amd64-cpython-38\sklearn\utils
#   copying sklearn\utils\_joblib.py -> build\lib.win-amd64-cpython-38\sklearn\utils
#   copying sklearn\utils\_scipy_sparse_lsqr_backport.py -> build\lib.win-amd64-cpython-38\sklearn\utils
#   copying sklearn\utils\_show_versions.py -> build\lib.win-amd64-cpython-38\sklearn\utils
#   copying sklearn\utils\_unittest_backport.py -> build\lib.win-amd64-cpython-38\sklearn\utils
#   copying sklearn\utils\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\utils
#   creating build\lib.win-amd64-cpython-38\sklearn\utils\sparsetools
#   copying sklearn\utils\sparsetools\setup.py -> build\lib.win-amd64-cpython-38\sklearn\utils\sparsetools
#   copying sklearn\utils\sparsetools\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\utils\sparsetools
#   creating build\lib.win-amd64-cpython-38\sklearn\utils\sparsetools\tests
#   copying sklearn\utils\sparsetools\tests\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\utils\sparsetools\tests
#   creating build\lib.win-amd64-cpython-38\sklearn\utils\tests
#   copying sklearn\utils\tests\test_bench.py -> build\lib.win-amd64-cpython-38\sklearn\utils\tests
#   copying sklearn\utils\tests\test_class_weight.py -> build\lib.win-amd64-cpython-38\sklearn\utils\tests
#   copying sklearn\utils\tests\test_deprecation.py -> build\lib.win-amd64-cpython-38\sklearn\utils\tests
#   copying sklearn\utils\tests\test_estimator_checks.py -> build\lib.win-amd64-cpython-38\sklearn\utils\tests
#   copying sklearn\utils\tests\test_extmath.py -> build\lib.win-amd64-cpython-38\sklearn\utils\tests
#   copying sklearn\utils\tests\test_fast_dict.py -> build\lib.win-amd64-cpython-38\sklearn\utils\tests
#   copying sklearn\utils\tests\test_fixes.py -> build\lib.win-amd64-cpython-38\sklearn\utils\tests
#   copying sklearn\utils\tests\test_graph.py -> build\lib.win-amd64-cpython-38\sklearn\utils\tests
#   copying sklearn\utils\tests\test_linear_assignment.py -> build\lib.win-amd64-cpython-38\sklearn\utils\tests
#   copying sklearn\utils\tests\test_metaestimators.py -> build\lib.win-amd64-cpython-38\sklearn\utils\tests
#   copying sklearn\utils\tests\test_multiclass.py -> build\lib.win-amd64-cpython-38\sklearn\utils\tests
#   copying sklearn\utils\tests\test_murmurhash.py -> build\lib.win-amd64-cpython-38\sklearn\utils\tests
#   copying sklearn\utils\tests\test_optimize.py -> build\lib.win-amd64-cpython-38\sklearn\utils\tests
#   copying sklearn\utils\tests\test_random.py -> build\lib.win-amd64-cpython-38\sklearn\utils\tests
#   copying sklearn\utils\tests\test_seq_dataset.py -> build\lib.win-amd64-cpython-38\sklearn\utils\tests
#   copying sklearn\utils\tests\test_shortest_path.py -> build\lib.win-amd64-cpython-38\sklearn\utils\tests
#   copying sklearn\utils\tests\test_show_versions.py -> build\lib.win-amd64-cpython-38\sklearn\utils\tests
#   copying sklearn\utils\tests\test_sparsefuncs.py -> build\lib.win-amd64-cpython-38\sklearn\utils\tests
#   copying sklearn\utils\tests\test_stats.py -> build\lib.win-amd64-cpython-38\sklearn\utils\tests
#   copying sklearn\utils\tests\test_testing.py -> build\lib.win-amd64-cpython-38\sklearn\utils\tests
#   copying sklearn\utils\tests\test_utils.py -> build\lib.win-amd64-cpython-38\sklearn\utils\tests
#   copying sklearn\utils\tests\test_validation.py -> build\lib.win-amd64-cpython-38\sklearn\utils\tests
#   copying sklearn\utils\tests\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\utils\tests
#   creating build\lib.win-amd64-cpython-38\sklearn\tests
#   copying sklearn\tests\test_base.py -> build\lib.win-amd64-cpython-38\sklearn\tests
#   copying sklearn\tests\test_calibration.py -> build\lib.win-amd64-cpython-38\sklearn\tests
#   copying sklearn\tests\test_check_build.py -> build\lib.win-amd64-cpython-38\sklearn\tests
#   copying sklearn\tests\test_common.py -> build\lib.win-amd64-cpython-38\sklearn\tests
#   copying sklearn\tests\test_config.py -> build\lib.win-amd64-cpython-38\sklearn\tests
#   copying sklearn\tests\test_discriminant_analysis.py -> build\lib.win-amd64-cpython-38\sklearn\tests
#   copying sklearn\tests\test_docstring_parameters.py -> build\lib.win-amd64-cpython-38\sklearn\tests
#   copying sklearn\tests\test_dummy.py -> build\lib.win-amd64-cpython-38\sklearn\tests
#   copying sklearn\tests\test_impute.py -> build\lib.win-amd64-cpython-38\sklearn\tests
#   copying sklearn\tests\test_init.py -> build\lib.win-amd64-cpython-38\sklearn\tests
#   copying sklearn\tests\test_isotonic.py -> build\lib.win-amd64-cpython-38\sklearn\tests
#   copying sklearn\tests\test_kernel_approximation.py -> build\lib.win-amd64-cpython-38\sklearn\tests
#   copying sklearn\tests\test_kernel_ridge.py -> build\lib.win-amd64-cpython-38\sklearn\tests
#   copying sklearn\tests\test_metaestimators.py -> build\lib.win-amd64-cpython-38\sklearn\tests
#   copying sklearn\tests\test_multiclass.py -> build\lib.win-amd64-cpython-38\sklearn\tests
#   copying sklearn\tests\test_multioutput.py -> build\lib.win-amd64-cpython-38\sklearn\tests
#   copying sklearn\tests\test_naive_bayes.py -> build\lib.win-amd64-cpython-38\sklearn\tests
#   copying sklearn\tests\test_pipeline.py -> build\lib.win-amd64-cpython-38\sklearn\tests
#   copying sklearn\tests\test_random_projection.py -> build\lib.win-amd64-cpython-38\sklearn\tests
#   copying sklearn\tests\test_site_joblib.py -> build\lib.win-amd64-cpython-38\sklearn\tests
#   copying sklearn\tests\__init__.py -> build\lib.win-amd64-cpython-38\sklearn\tests
#   running build_clib
#   INFO: No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   INFO: customize MSVCCompiler
#   WARN: Missing compiler_cxx fix for MSVCCompiler
#   INFO: customize MSVCCompiler using build_clib
#   INFO: CCompilerOpt.cc_test_flags[1077] : testing flags (/O2)
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   INFO: CCompilerOpt.cache_flush[857] : write cache to path -> C:\Users\user\AppData\Local\Temp\pip-install-05dhrub9\scikit-learn_0b73a366545b41d09a8528ab0b05dc2c\build\temp.win-amd64-cpython-38\ccompiler_opt_cache_clib.py
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for scikit-learn
# ERROR: Could not build wheels for scikit-learn, which is required to install pyproject.toml-based projects

# %%
from sklearn.impute import SimpleImputer
import pandas as pd
import numpy as np
# Checking for missing values in the data
print("Number of missing values in loan_n:")
print(loan_n.isnull().sum())

# Handling missing values in loan_n
loan_n.fillna(loan_n.mean(), inplace=True)  # Filling NaN values with mean

# Creating an instance of SimpleImputer
imputer = SimpleImputer(strategy='mean')

# Fitting the imputer on the data
imputer.fit(loan_n)

# Transforming the data
loan_n_imputed = imputer.transform(loan_n)

# Converting the transformed data into DataFrame
loan_d = pd.DataFrame(loan_n_imputed)
# Out:
# Number of missing values in loan_n:
# LoanAmount          22
# Loan_Amount_Term    14
# Credit_History      50
# dtype: int64

# %%
loan.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
loan['LoanAmount'],loan['Loan_Amount_Term'], loan['Credit_History'] = loan_d[0], loan_d[1], loan_d[2]

# %%
loan.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
employ = loan['Self_Employed']
P_area = loan['Property_Area']
gender = loan["Gender"]
status = loan["Married"]
education = loan["Education"]
loan_status = loan['Loan_Status']


status = status.fillna("Yes")
gender = gender.fillna("Male")
P_area= P_area.fillna("Rural")
employ= employ.fillna("Yes")
dependat = dependat.fillna(1)

from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

#========Initializing String to be Encoded==========

input_class = ["Male", "Female"]
input_class1 = ["Yes", "No"]
input_class2 = ["Rural", "Urban", "Semiurban"]
input_class3 = ["Graduate", "Not Graduate"]
input_class4 = ["Y", "N"]

label_encoder.fit(input_class)


gender = gender.iloc[:].values
gender = list(gender)
gender = label_encoder.transform(gender)

label_encoder.fit(input_class1)

status = status.iloc[:].values
employ = employ.iloc[:].values
employ = list(employ)
status = list(status)
status = label_encoder.transform(status)
employ = label_encoder.transform(employ)


label_encoder.fit(input_class2)

P_area = P_area.iloc[:].values
P_area = list(P_area)
P_area = label_encoder.transform(P_area)

label_encoder.fit(input_class3)

education = education.iloc[:].values
education = list(education)
education = label_encoder.transform(education)

label_encoder.fit(input_class4)

loan_status = loan_status.iloc[:].values
loan_status =list(loan_status)
loan_status = label_encoder.transform(loan_status)

# %%
loan['Education'],loan['Self_Employed'],loan['Property_Area'],loan["Gender"],loan["Married"], loan['Loan_Status'], loan['Dependents'] =education, employ, P_area, gender, status, loan_status, dependat

# %%
loan.head()
loan.to_csv("Loan Processed data.csv")

# %%
data = loan.iloc[:, 1:-1]
target = loan.iloc[:, -1:]

# %%
data.head(5)
# Out:
#    Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0       1        0          0          0              0             5849
# 1       1        1          1          0              0             4583
# 2       1        1          0          0              1             3000
# 3       1        1          0          1              0             2583
# 4       1        0          0          0              0             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0  146.412162             360.0             1.0
# 1             1508.0  128.000000             360.0             1.0
# 2                0.0   66.000000             360.0             1.0
# 3             2358.0  120.000000             360.0             1.0
# 4                0.0  141.000000             360.0             1.0
#
#    Property_Area
# 0              2
# 1              0
# 2              2
# 3              2
# 4              2

# %%
target.head(2)
# Out:
#    Loan_Status
# 0            1
# 1            0

# %%
data.to_csv("Data.csv")
target.to_csv("Target.csv")

# %%
x_train, x_test, y_train, y_test = train_test_split(data, target, test_size = 1/5, random_state=10)

# %%
model_a = RandomForestClassifier()
model_a.fit(x_train, y_train)
pred = model_a.predict(x_test)
forest = accuracy_score(y_test, pred)



from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier()
model.fit(x_train, y_train)
pred = model.predict(x_test)
k = accuracy_score(y_test, pred)


from sklearn.naive_bayes import MultinomialNB
model = MultinomialNB()
model.fit(x_train, y_train)
pred = model.predict(x_test)
MB= accuracy_score(y_test, pred)

from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x_train, y_train)
pred = model.predict(x_test)
GB=accuracy_score(y_test, pred)

from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train, y_train)
pred = model.predict(x_test)
LR=accuracy_score(y_test, pred)

from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(x_train, y_train)
pred = model.predict(x_test)
DTC=  accuracy_score(y_test, pred)

print ("""The result were as Follows\nRandom Forest Classifer {}\n\n K Nearest Neighbors {}
\n\nMultinomial NB {}\n\nGaussian NB {}\n\nLogistic Regression {}\n\n Decision Tree Classifier {}
""".format(forest,k, MB, GB, LR, DTC))
# Out:
# The result were as Follows
# Random Forest Classifer 0.7886178861788617
#
#  K Nearest Neighbors 0.6097560975609756
#
#
# Multinomial NB 0.5365853658536586
#
# Gaussian NB 0.7804878048780488
#
# Logistic Regression 0.7967479674796748
#
#  Decision Tree Classifier 0.7235772357723578
# C:\Users\user\AppData\Local\Temp\ipykernel_8616\2658692152.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model_a.fit(x_train, y_train)
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\sklearn\neighbors\_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
import joblib

# %%
joblib.dump(model_a, "model.pkl")
# Out:
# ['model.pkl']

# %%
n= data.iloc[:,:].values

# %%
m = n[0]
m = np.array([m])

# %%
model.predict(m)
# Out:
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array([1])
